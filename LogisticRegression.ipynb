# %% [markdown]
# <a href="https://colab.research.google.com/github/makaronaaa/DataSciencePython/blob/main/LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import seaborn as sb
from sklearn import metrics

df=pd.read_csv('/content/sample_data/data_banknote_authentication.csv')
df['color'] = np.where(df['class']== 0 , 'green', 'red')
df
# Out:
#       variance  skewness  curtosis  entropy  class  color
# 0      3.62160   8.66610   -2.8073 -0.44699      0  green
# 1      4.54590   8.16740   -2.4586 -1.46210      0  green
# 2      3.86600  -2.63830    1.9242  0.10645      0  green
# 3      3.45660   9.52280   -4.0112 -3.59440      0  green
# 4      0.32924  -4.45520    4.5718 -0.98880      0  green
# ...        ...       ...       ...      ...    ...    ...
# 1367   0.40614   1.34920   -1.4501 -0.55949      1    red
# 1368  -1.38870  -4.87730    6.4774  0.34179      1    red
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1    red
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1    red
# 1371  -2.54190  -0.65804    2.6842  1.19520      1    red
#
# [1372 rows x 6 columns]

# %%
X = df[["variance","skewness","curtosis", "entropy"]].values # Features
Y = df[['color']].values # Target variable
X_train,X_test,X1_train,X1_test,X2_train,X2_test,X3_train,X3_test,X4_train,X4_test,Y_train,Y_test = train_test_split(X,X1,X2,X3,X4,Y,test_size = 0.5)

#scale
scaler = StandardScaler()
scaler.fit(X_train)
xtrain = scaler.fit_transform(X_train) 
xtest = scaler.transform(X_test)

classifier = LogisticRegression()
# fit the model with data
classifier.fit(X_train, Y_train)
y_pred = classifier.predict(X_test)

from sklearn.metrics import accuracy_score
accur=accuracy_score(Y_test, y_pred)
print ("Accuracy : ", round(100*accur),2)
# Out:
# Accuracy :  98 2
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#confusion metrix- accuracy btw positive and negative labels
cm = confusion_matrix(Y_test, y_pred)  #check the model performance on predicted values and actual values.
tp = cm[0][0]
fn = cm[0][1]
fp = cm[1][0]
tn = cm[1][1]
print ("Confusion Matrix : \n", cm)
print("TP=", tp,"    FP=",  fp,"    FN=",  fn,"   TN=",  tn)
tpr = tp / (tp + fn)
tnr = tn / (tn + fp)
acc = (tp + tn) / (tp + tn + fp + fn)
print("TPR=", tpr, "    TNR=", tnr, "    ACC=", acc)

X_accuracy= round(100*(tp + tn)/(tp + tn + fp + fn), 2)
print("Accuracy",X_accuracy)
# Out:
# Confusion Matrix :
#  [[367  10]
#  [  1 308]]
# TP= 367     FP= 1     FN= 10    TN= 308
# TPR= 0.9734748010610079     TNR= 0.9967637540453075     ACC= 0.9839650145772595
# Accuracy 98.4

# %%
X = df[["variance","skewness","curtosis", "entropy"]].values
X1 = df[["skewness","curtosis", "entropy"]].values #f1 is missing
X2 = df[["variance","curtosis", "entropy"]].values #f2 missing
X3 = df[["variance","skewness", "entropy"]].values #just f3 missing
X4 = df[["variance","skewness","curtosis"]].values #just f4 is missing
Y = df[["color"]].values
X_train,X_test,X1_train,X1_test,X2_train,X2_test,X3_train,X3_test,X4_train,X4_test,Y_train,Y_test = train_test_split(X,X1,X2,X3,X4,Y,test_size = 0.5)

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.fit_transform(X_train) 
X_test = scaler.transform(X_test)

classifier = LogisticRegression()
# fit the model with data
classifier.fit(X_train, Y_train)

pred = classifier.predict(X_test)
# cm = confusion_matrix(Y_test, y_pred)  #check the model performance on predicted values and actual values.
# tp = cm[0][0]
# fn = cm[0][1]
# fp = cm[1][0]
# tn = cm[1][1]
X_accuracy = round(100*np.mean(pred == Y_test) ,2)
print("Accuracy  ", X_accuracy, "%")

scaler.fit(X1_train)
X1_train = scaler.transform(X1_train)
X1_test = scaler.transform(X1_test)
classifier = LogisticRegression()
classifier.fit(X1_train, Y_train)
pred = classifier.predict(X1_test)
cm = confusion_matrix(Y_test, pred)  #check the model performance on predicted values and actual values.
tp = cm[0][0]
fn = cm[0][1]
fp = cm[1][0]
tn = cm[1][1]
X1_accuracy = round(100*(tp + tn)/(tp + tn + fp + fn) , 2)
print("Accuracy f1 missing: ", X1_accuracy, "%")
print("Loss in accuracy due to dropping f1: ", round(X_accuracy-X1_accuracy, 2))

scaler.fit(X2_train)
X2_train = scaler.transform(X2_train)
X2_test = scaler.transform(X2_test)
classifier = LogisticRegression()
classifier.fit(X1_train, Y_train)
pred = classifier.predict(X2_test)
# cm = confusion_matrix(Y_test, pred)  #check the model performance on predicted values and actual values.
# tp = cm[0][0]
# fn = cm[0][1]
# fp = cm[1][0]
# tn = cm[1][1]
X2_accuracy = round(100*(tp + tn)/(tp + tn + fp + fn) , 2)
print("Accuracy f2 missing: ", X2_accuracy, "%")
print("Loss in accuracy due to dropping f2: ", round(X_accuracy-X2_accuracy, 2))

scaler.fit(X1_train)
X3_train = scaler.transform(X3_train)
X3_test = scaler.transform(X3_test)
classifier = LogisticRegression()
classifier.fit(X3_train, Y_train)
pred = classifier.predict(X3_test)
cm = confusion_matrix(Y_test, pred)  #check the model performance on predicted values and actual values.
tp = cm[0][0]
fn = cm[0][1]
fp = cm[1][0]
tn = cm[1][1]
X3_accuracy = round(100*(tp + tn)/(tp + tn + fp + fn) , 2)
print("Accuracy f3 missing: ", X3_accuracy, "%")
print("Loss in accuracy due to dropping f3: ", round(X_accuracy-X3_accuracy, 2))

scaler.fit(X4_train)
X4_train = scaler.transform(X4_train)
X4_test = scaler.transform(X4_test)
classifier = LogisticRegression()
classifier.fit(X4_train, Y_train)
pred = classifier.predict(X4_test)
cm = confusion_matrix(Y_test, pred)  #check the model performance on predicted values and actual values.
tp = cm[0][0]
fn = cm[0][1]
fp = cm[1][0]
tn = cm[1][1]
X2_accuracy = round(100*(tp + tn)/(tp + tn + fp + fn) , 2)
print("Accuracy ,f4 missing: ", X2_accuracy, "%")
print("Loss in accuracy due to dropping f4: ", round(X_accuracy-X2_accuracy, 2))
# Out:
# Accuracy   50.28 %
# Accuracy f1 missing:  79.88 %
# Loss in accuracy due to dropping f1:  -29.6
# Accuracy f2 missing:  79.88 %
# Loss in accuracy due to dropping f2:  -29.6
# Accuracy f3 missing:  85.13 %
# Loss in accuracy due to dropping f3:  -34.85
# Accuracy ,f4 missing:  97.52 %
# Loss in accuracy due to dropping f4:  -47.24
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
#   #####LOGISTIC REGRESSION
# -a statistical analysis method to predict a binary outcome, such as yes or no, based on prior observations of a data set(values)
# -(used when the prediction is categorical, for exp Y/N, true/false, 0 or 1. The predicted probability or output of log regression can be either one of them, and there's no middle ground.)
# -generally no scalling(we don't calculate distance), but to compare features we scale.
