# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\maka\OneDrive\Desktop\Assignment_4\sleep_analysis\Sleep_Efficiency.csv")
df
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    24
# ...

# %%
children = df[df["Age"] <= 12]
children
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 9     10   11  Female  2021-09-16 01:00:00  2021-09-16 10:00:00
# 52    53    9  Female  2021-11-27 01:00:00  2021-11-27 09:30:00
# 211  212   10  Female  2021-07-15 01:00:00  2021-07-15 08:00:00
# 332  333   12  Female  2021-11-01 01:00:00  2021-11-01 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 9               9.0              0.55                    18
# 52              8.5              0.52                    18
# 211             7.0              0.54                    18
# 332             9.0              0.56                    18
#
#      Deep sleep percentage  Light sleep percentage  Awakenings  \
# 9                       35                      45         4.0
# 52                      35                      45         2.0
# 211                     35                      45         3.0
# 332                     35                      45         1.0
#
# ...

# %%
#2. how many different entries are there for each columns.
# Find number of unique entries in each column
unique_entries = df.nunique()
print(unique_entries)
# Out:
# ID                        452
# Age                        61
# Gender                      2
# Bedtime                   424
# Wakeup time               434
# Sleep duration              9
# Sleep efficiency           50
# REM sleep percentage       11
# Deep sleep percentage      18
# Light sleep percentage     21
# Awakenings                  5
# Caffeine consumption        6
# Alcohol consumption         6
# Smoking status              2
# Exercise frequency          6
# dtype: int64

# %%
#3. how many entries are missing for each column
# Find number of missing entries in each column
missing_entries = df.isna().sum()
print(missing_entries)
# Out:
# ID                         0
# Age                        0
# Gender                     0
# Bedtime                    0
# Wakeup time                0
# Sleep duration             0
# Sleep efficiency           0
# REM sleep percentage       0
# Deep sleep percentage      0
# Light sleep percentage     0
# Awakenings                20
# Caffeine consumption      25
# Alcohol consumption       16
# Smoking status             0
# Exercise frequency         6
# dtype: int64

# %%
#4. for each missing entry, impute the missing values using the following procedure:
#(a) find 5 people with the same gender with the closest age(”neighbors”)
import pandas as pd

# summarize the number of rows with missing values for each column
for i in range(len(df)):
    miss = df.isnull().sum()
    #perc = miss / df * 100
    print( 'Missing:', miss)
# Out:
# Missing: ID                         0
# Age                        0
# Gender                     0
# Bedtime                    0
# Wakeup time                0
# Sleep duration             0
# Sleep efficiency           0
# REM sleep percentage       0
# Deep sleep percentage      0
# Light sleep percentage     0
# Awakenings                20
# Caffeine consumption      25
# Alcohol consumption       16
# Smoking status             0
# Exercise frequency         6
# dtype: int64
# Missing: ID                         0
# Age                        0
# Gender                     0
# Bedtime                    0
# Wakeup time                0
# Sleep duration             0
# Sleep efficiency           0
# REM sleep percentage       0
# Deep sleep percentage      0
# Light sleep percentage     0
# Awakenings                20
# Caffeine consumption      25
# Alcohol consumption       16
# Smoking status             0
# Exercise frequency         6
# dtype: int64
# ...

# %%
#Q5

# %%
children = df[df["Age"] <= 12]
children
#the mean and standard deviation
# print('Avg of children:', round(df["Age"].fillna(df["Age"].mean()).astype('float'),2))
# Out:
#       ID   Age  Gender              Bedtime          Wakeup time  \
# 9     10  11.0  Female  2021-09-16 01:00:00  2021-09-16 10:00:00
# 52    53   9.0  Female  2021-11-27 01:00:00  2021-11-27 09:30:00
# 211  212  10.0  Female  2021-07-15 01:00:00  2021-07-15 08:00:00
# 332  333  12.0  Female  2021-11-01 01:00:00  2021-11-01 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 9               9.0              0.55                    18
# 52              8.5              0.52                    18
# 211             7.0              0.54                    18
# 332             9.0              0.56                    18
#
#      Deep sleep percentage  Light sleep percentage  Awakenings  \
# 9                       35                      45         4.0
# 52                      35                      45         2.0
# 211                     35                      45         3.0
# 332                     35                      45         1.0
#
# ...

# %%
f_child=df[df['Gender']=='Female']
f_child
# Out:
#       ID   Age  Gender              Bedtime          Wakeup time  \
# 0      1  65.0  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 2      3  40.0  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4  40.0  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 5      6  36.0  Female  2021-07-01 21:00:00  2021-07-01 04:30:00
# 6      7  27.0  Female  2021-07-21 21:00:00  2021-07-21 03:00:00
# ..   ...   ...     ...                  ...                  ...
# 442  443  27.0  Female  2021-02-06 01:30:00  2021-02-06 08:30:00
# 443  444  65.0  Female  2021-09-05 02:00:00  2021-09-05 09:30:00
# 445  446  30.0  Female  2021-11-16 23:00:00  2021-11-16 06:30:00
# 447  448  27.0  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 449  450  40.0  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 2               8.0              0.89                    20
# ...

# %%
# the mean and standard deviation
child = children.groupby('Gender')['Age'].mean()
print("Avg of AGE children",child )
child = children.groupby('Gender')['Age'].std()
print("St Dev of AGE children",child,'\n' )

child = children.groupby('Gender')['Sleep duration'].mean()
print("Avg of Sleep duration children",child )
child = children.groupby('Gender')['Sleep duration'].std()
print("St Dev of Sleep duration children",child ,'\n')

child = children.groupby('Gender')['Sleep efficiency'].mean()
print("Avg of Sleep efficiency children",child )
child= children.groupby('Gender')['Sleep efficiency'].std()
print("St Dev of Sleep efficiency children",child ,'\n')

child = children.groupby('Gender')['REM sleep percentage'].mean()
print("Avg of REM sleep percentage children",child)
child = children.groupby('Gender')['REM sleep percentage'].std()
print("St Dev of REM sleep percentage child",child ,'\n')

child = children.groupby('Gender')['Deep sleep percentage'].mean()
print("Avg of Deep sleep percentage children",child )
child = children.groupby('Gender')['Deep sleep percentage'].std()
print("St Dev of Deep sleep percentage children",child ,'\n')

child = children.groupby('Gender')['Light sleep percentage'].mean()
print("Avg of Light sleep percentage children",child )
child = children.groupby('Gender')['Light sleep percentage'].std()
print("St Dev of Light sleep percentage children",child ,'\n')

child = children.groupby('Gender')['Awakenings'].mean()
print("Avg of Awakenings children",child )
child = children.groupby('Gender')['Awakenings'].std()
print("St Dev of Awakenings children",child ,'\n')

child= children.groupby('Gender')['Exercise frequency'].mean()
print("Avg of Exercise frequency children",child )
child = children.groupby('Gender')['Exercise frequency'].std()
print("St Dev of Exercise frequency children",child ,'\n')

child = children.groupby('Gender')['Alcohol consumption'].mean()
print("Avg of Alcohol consumption  children",child )
child = children.groupby('Gender')['Alcohol consumption'].std()
print("St Dev of Alcohol consumption children",child ,'\n')

child = children.groupby('Gender')['Exercise frequency'].mean()
print("Avg of Exercise frequency  children",child)
child = children.groupby('Gender')['Exercise frequency'].std()
print("St Dev of Exercise frequency children",child ,'\n')
# Out:
# Avg of AGE children Gender
# Female    10.5
# Name: Age, dtype: float64
# St Dev of AGE children Gender
# Female    1.290994
# Name: Age, dtype: float64
#
# Avg of Sleep duration children Gender
# Female    8.375
# Name: Sleep duration, dtype: float64
# St Dev of Sleep duration children Gender
# Female    0.946485
# Name: Sleep duration, dtype: float64
#
# Avg of Sleep efficiency children Gender
# Female    0.5425
# Name: Sleep efficiency, dtype: float64
# St Dev of Sleep efficiency children Gender
# Female    0.017078
# Name: Sleep efficiency, dtype: float64
#
# Avg of REM sleep percentage children Gender
# Female    18.0
# Name: REM sleep percentage, dtype: float64
# St Dev of REM sleep percentage child Gender
# Female    0.0
# Name: REM sleep percentage, dtype: float64
#
# Avg of Deep sleep percentage children Gender
# Female    35.0
# Name: Deep sleep percentage, dtype: float64
# St Dev of Deep sleep percentage children Gender
# Female    0.0
# ...

# %%
m_child=children[children['Gender']=='Male']
m_child
#the mean and standard deviation
# Out:
# Empty DataFrame
# Columns: [ID, Age, Gender, Bedtime, Wakeup time, Sleep duration, Sleep efficiency, REM sleep percentage, Deep sleep percentage, Light sleep percentage, Awakenings, Caffeine consumption, Alcohol consumption, Smoking status, Exercise frequency]
# Index: []

# %%
teenagers = df[(df["Age"]>=13) & (df["Age"]<=17)]
teenagers
#the mean and standard deviation
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 53    54   16  Female  2021-08-31 01:00:00  2021-08-31 09:30:00
# 121  122   15  Female  2021-07-24 01:00:00  2021-07-24 09:00:00
# 158  159   14  Female  2021-02-02 01:00:00  2021-02-02 08:00:00
# 219  220   13  Female  2021-03-11 01:00:00  2021-03-11 09:00:00
# 284  285   17  Female  2021-12-08 02:00:00  2021-12-08 09:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 53              8.5              0.65                    18
# 121             8.0              0.62                    18
# 158             7.0              0.60                    18
# 219             8.0              0.58                    18
# 284             7.0              0.68                    22
#
#      Deep sleep percentage  Light sleep percentage  Awakenings  \
# 53                      35                      45         2.0
# 121                     35                      45         1.0
# ...

# %%
f_teenagers=df[df['Gender']=='Female']
f_teenagers
#the mean and standard deviation
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 5      6   36  Female  2021-07-01 21:00:00  2021-07-01 04:30:00
# 6      7   27  Female  2021-07-21 21:00:00  2021-07-21 03:00:00
# ..   ...  ...     ...                  ...                  ...
# 442  443   27  Female  2021-02-06 01:30:00  2021-02-06 08:30:00
# 443  444   65  Female  2021-09-05 02:00:00  2021-09-05 09:30:00
# 445  446   30  Female  2021-11-16 23:00:00  2021-11-16 06:30:00
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 2               8.0              0.89                    20
# ...

# %%
m_teenagers=df[df['Gender']=='Male']
m_teenagers

# %%
teen=df[['Gender','Age', 'Sleep duration', 'Sleep efficiency', 'REM sleep percentage', 'Deep sleep percentage', 'Light sleep percentage', 'Awakenings', 'Alcohol consumption', 'Exercise frequency']][(df["Age"]>=13) & (df["Age"]<=17)]
teen.groupby('Gender').mean()
# Out:
#          Age  Sleep duration  Sleep efficiency  REM sleep percentage  \
# Gender
# Female  15.0             7.7             0.626                  18.8
#
#         Deep sleep percentage  Light sleep percentage  Awakenings  \
# Gender
# Female                   32.6                    46.8         2.0
#
#         Alcohol consumption  Exercise frequency
# Gender
# Female                  3.0                 0.0

# %%
teen.groupby('Gender').std()
# Out:
#              Age  Sleep duration  Sleep efficiency  REM sleep percentage  \
# Gender
# Female  1.581139         0.67082          0.039749              1.788854
#
#         Deep sleep percentage  Light sleep percentage  Awakenings  \
# Gender
# Female               5.366563                4.024922         1.0
#
#         Alcohol consumption  Exercise frequency
# Gender
# Female             2.645751                 0.0

# %%
young_adults=df[(df["Age"]>=18) & (df["Age"]<=30)]
young_adults
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 6      7   27  Female  2021-07-21 21:00:00  2021-07-21 03:00:00
# 12    13   30  Female  2021-08-07 02:30:00  2021-08-07 11:30:00
# 13    14   28    Male  2021-02-25 01:00:00  2021-02-25 09:30:00
# 16    17   21  Female  2021-03-24 01:00:00  2021-03-24 08:00:00
# 20    21   24    Male  2021-05-02 00:00:00  2021-05-02 08:00:00
# ..   ...  ...     ...                  ...                  ...
# 444  445   24    Male  2021-05-07 00:00:00  2021-05-07 07:30:00
# 445  446   30  Female  2021-11-16 23:00:00  2021-11-16 06:30:00
# 446  447   23    Male  2021-04-21 00:00:00  2021-04-21 07:00:00
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 6               6.0              0.54                    28
# 12              9.0              0.93                    24
# ...

# %%
f_young_adults=df[df['Gender']=='Female']
f_young_adults
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 5      6   36  Female  2021-07-01 21:00:00  2021-07-01 04:30:00
# 6      7   27  Female  2021-07-21 21:00:00  2021-07-21 03:00:00
# ..   ...  ...     ...                  ...                  ...
# 442  443   27  Female  2021-02-06 01:30:00  2021-02-06 08:30:00
# 443  444   65  Female  2021-09-05 02:00:00  2021-09-05 09:30:00
# 445  446   30  Female  2021-11-16 23:00:00  2021-11-16 06:30:00
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 2               8.0              0.89                    20
# ...

# %%
m_young_adults=df[df['Gender']=='Male']
m_young_adults
# Out:
#       ID  Age Gender              Bedtime          Wakeup time  \
# 1      2   69   Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 4      5   57   Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# 7      8   53   Male  2021-08-16 00:30:00  2021-08-16 10:30:00
# 10    11   50   Male  2021-02-28 00:30:00  2021-02-28 08:30:00
# 11    12   55   Male  2021-03-10 22:30:00  2021-03-10 06:00:00
# ..   ...  ...    ...                  ...                  ...
# 444  445   24   Male  2021-05-07 00:00:00  2021-05-07 07:30:00
# 446  447   23   Male  2021-04-21 00:00:00  2021-04-21 07:00:00
# 448  449   52   Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 450  451   45   Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18   Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 1               7.0              0.66                    24
# 4               8.0              0.76                    27
# ...

# %%
#the mean and standard deviation
young_adults=df[['Gender','Age', 'Sleep duration', 'Sleep efficiency', 'REM sleep percentage', 'Deep sleep percentage', 'Light sleep percentage', 'Awakenings', 'Alcohol consumption', 'Exercise frequency']][(df["Age"]>=18) & (df["Age"]<=30)]
young_adults.groupby('Gender').mean()
# Out:
#               Age  Sleep duration  Sleep efficiency  REM sleep percentage  \
# Gender
# Female  26.382353        7.558824          0.787794             25.073529
# Male    24.474576        7.449153          0.753220             22.050847
#
#         Deep sleep percentage  Light sleep percentage  Awakenings  \
# Gender
# Female              53.676471               24.132353    1.447761
# Male                50.898305               28.118644    1.945455
#
#         Alcohol consumption  Exercise frequency
# Gender
# Female             0.939394            1.470588
# Male               2.018519            2.125000

# %%
young_adults.groupby('Gender').std()
# Out:
#              Age  Sleep duration  Sleep efficiency  REM sleep percentage  \
# Gender
# Female  3.255441        0.874726           0.13661              3.279589
# Male    2.990536        0.661079           0.14229              4.535012
#
#         Deep sleep percentage  Light sleep percentage  Awakenings  \
# Gender
# Female              14.550418               14.318243    1.340325
# Male                19.078508               17.133437    1.419679
#
#         Alcohol consumption  Exercise frequency
# Gender
# Female             1.587245            1.332382
# Male               1.966615            1.079773

# %%
adults=df[(df["Age"]>=31) & (df["Age"]<=60)]
adults
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# 5      6   36  Female  2021-07-01 21:00:00  2021-07-01 04:30:00
# 7      8   53    Male  2021-08-16 00:30:00  2021-08-16 10:30:00
# ..   ...  ...     ...                  ...                  ...
# 438  439   55    Male  2021-04-14 01:30:00  2021-04-14 07:30:00
# 441  442   46    Male  2021-03-30 00:00:00  2021-03-30 09:00:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 2               8.0              0.89                    20
# 3               6.0              0.51                    28
# ...

# %%
f_adults=df[df['Gender']=='Female']
f_adults
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 5      6   36  Female  2021-07-01 21:00:00  2021-07-01 04:30:00
# 6      7   27  Female  2021-07-21 21:00:00  2021-07-21 03:00:00
# ..   ...  ...     ...                  ...                  ...
# 442  443   27  Female  2021-02-06 01:30:00  2021-02-06 08:30:00
# 443  444   65  Female  2021-09-05 02:00:00  2021-09-05 09:30:00
# 445  446   30  Female  2021-11-16 23:00:00  2021-11-16 06:30:00
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 2               8.0              0.89                    20
# ...

# %%
m_adults=df[df['Gender']=='Male']
m_adults
# Out:
#       ID  Age Gender              Bedtime          Wakeup time  \
# 1      2   69   Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 4      5   57   Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# 7      8   53   Male  2021-08-16 00:30:00  2021-08-16 10:30:00
# 10    11   50   Male  2021-02-28 00:30:00  2021-02-28 08:30:00
# 11    12   55   Male  2021-03-10 22:30:00  2021-03-10 06:00:00
# ..   ...  ...    ...                  ...                  ...
# 444  445   24   Male  2021-05-07 00:00:00  2021-05-07 07:30:00
# 446  447   23   Male  2021-04-21 00:00:00  2021-04-21 07:00:00
# 448  449   52   Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 450  451   45   Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18   Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 1               7.0              0.66                    24
# 4               8.0              0.76                    27
# ...

# %%
#the mean and standard deviation
adult= adults.groupby('Gender')['Age'].mean()
print("Avg of AGE ",adult)
adult = adults.groupby('Gender')['Age'].std()
print("St Dev of AGE ",adult,'\n' )

adult = adults.groupby('Gender')['Sleep duration'].mean()
print("Avg of Sleep duration ",adult)
adult= adults.groupby('Gender')['Sleep duration'].std()
print("St Dev of Sleep duration",adult,'\n')

adult = adults.groupby('Gender')['Sleep efficiency'].mean()
print("Avg of Sleep efficiency",adult )
adult = adults.groupby('Gender')['Sleep efficiency'].std()
print("St Dev of Sleep efficiency ",adult,'\n')

adult = adults.groupby('Gender')['REM sleep percentage'].mean()
print("Avg of REM sleep percentage ",adult )
adult = adults.groupby('Gender')['REM sleep percentage'].std()
print("St Dev of REM sleep percentage ",adult ,'\n')

adult = adults.groupby('Gender')['Deep sleep percentage'].mean()
print("Avg of Deep sleep percentage ",adult)
adult = adults.groupby('Gender')['Deep sleep percentage'].std()
print("St Dev of Deep sleep percentage ",adult ,'\n')

adult = adults.groupby('Gender')['Light sleep percentage'].mean()
print("Avg of Light sleep percentage ",adult)
adult = adults.groupby('Gender')['Light sleep percentage'].std()
print("St Dev of Light sleep percentage ",adult,'\n')

adult = adults.groupby('Gender')['Awakenings'].mean()
print("Avg of Awakenings ",adult)
adult= adults.groupby('Gender')['Awakenings'].std()
print("St Dev of Awakenings ",adult ,'\n')

adult = adults.groupby('Gender')['Exercise frequency'].mean()
print("Avg of Exercise frequency",adult)
adult = adults.groupby('Gender')['Exercise frequency'].std()
print("St Dev of Exercise frequency ",adult,'\n')

adult = adults.groupby('Gender')['Alcohol consumption'].mean()
print("Avg of Alcohol consumption ",adult)
adult = adults.groupby('Gender')['Alcohol consumption'].std()
print("St Dev ofAlcohol consumption",adult ,'\n')

adult = adults.groupby('Gender')['Exercise frequency'].mean()
print("Avg of Exercise frequency  children",adult )
adult = adults.groupby('Gender')['Exercise frequency'].std()
print("St Dev of Exercise frequency children",adult ,'\n')
# Out:
# Avg of AGE  Gender
# Female    41.196970
# Male      48.647059
# Name: Age, dtype: float64
# St Dev of AGE  Gender
# Female    7.389325
# Male      6.945721
# Name: Age, dtype: float64
#
# Avg of Sleep duration  Gender
# Female    7.443182
# Male      7.398693
# Name: Sleep duration, dtype: float64
# St Dev of Sleep duration Gender
# Female    0.872934
# Male      0.912918
# Name: Sleep duration, dtype: float64
#
# Avg of Sleep efficiency Gender
# Female    0.805833
# Male      0.806078
# Name: Sleep efficiency, dtype: float64
# St Dev of Sleep efficiency  Gender
# Female    0.139229
# Male      0.121700
# Name: Sleep efficiency, dtype: float64
#
# Avg of REM sleep percentage  Gender
# Female    23.393939
# Male      22.392157
# Name: REM sleep percentage, dtype: float64
# St Dev of REM sleep percentage  Gender
# Female    3.922450
# Male      3.789243
# Name: REM sleep percentage, dtype: float64
#
# Avg of Deep sleep percentage  Gender
# Female    53.113636
# Male      55.130719
# ...

# %%
older_adults = df[df["Age"] >= 65]
older_adults
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 51    52   65    Male  2021-08-27 02:30:00  2021-08-27 10:00:00
# 82    83   66    Male  2021-07-03 02:00:00  2021-07-03 09:30:00
# 99   100   65    Male  2021-12-07 01:30:00  2021-12-07 09:30:00
# 144  145   65  Female  2021-03-26 02:00:00  2021-03-26 09:00:00
# 150  151   65    Male  2021-04-15 01:00:00  2021-04-15 09:30:00
# 154  155   68    Male  2021-03-19 02:00:00  2021-03-19 09:30:00
# 245  246   67    Male  2021-02-06 01:00:00  2021-02-06 09:30:00
# 255  256   65  Female  2021-06-23 02:00:00  2021-06-23 09:00:00
# 305  306   65    Male  2021-11-21 00:30:00  2021-11-21 05:30:00
# 341  342   65  Female  2021-03-18 00:00:00  2021-03-18 08:00:00
# 359  360   65  Female  2021-03-11 01:00:00  2021-03-11 10:00:00
# 374  375   65    Male  2021-08-13 01:30:00  2021-08-13 09:00:00
# ...

# %%
f_older_adults=df[df['Gender']=='Female']
f_older_adults
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 5      6   36  Female  2021-07-01 21:00:00  2021-07-01 04:30:00
# 6      7   27  Female  2021-07-21 21:00:00  2021-07-21 03:00:00
# ..   ...  ...     ...                  ...                  ...
# 442  443   27  Female  2021-02-06 01:30:00  2021-02-06 08:30:00
# 443  444   65  Female  2021-09-05 02:00:00  2021-09-05 09:30:00
# 445  446   30  Female  2021-11-16 23:00:00  2021-11-16 06:30:00
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 2               8.0              0.89                    20
# ...

# %%
m_older_adults=df[df['Gender']=='Male']
m_older_adults
# Out:
#       ID  Age Gender              Bedtime          Wakeup time  \
# 1      2   69   Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 4      5   57   Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# 7      8   53   Male  2021-08-16 00:30:00  2021-08-16 10:30:00
# 10    11   50   Male  2021-02-28 00:30:00  2021-02-28 08:30:00
# 11    12   55   Male  2021-03-10 22:30:00  2021-03-10 06:00:00
# ..   ...  ...    ...                  ...                  ...
# 444  445   24   Male  2021-05-07 00:00:00  2021-05-07 07:30:00
# 446  447   23   Male  2021-04-21 00:00:00  2021-04-21 07:00:00
# 448  449   52   Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 450  451   45   Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18   Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 1               7.0              0.66                    24
# 4               8.0              0.76                    27
# ...

# %%
#the mean and standard deviation
older = older_adults.groupby('Gender')['Age'].mean()
print("Avg of AGE ",older )
older = older_adults.groupby('Gender')['Age'].std()
print("St Dev of AGE ",older,'\n' )

older = older_adults.groupby('Gender')['Sleep duration'].mean()
print("Avg of Sleep duration ",older )
adults = older_adults.groupby('Gender')['Sleep duration'].std()
print("St Dev of Sleep duration",adults ,'\n')

older = older_adults.groupby('Gender')['Sleep efficiency'].mean()
print("Avg of Sleep efficiency",older )
older = older_adults.groupby('Gender')['Sleep efficiency'].std()
print("St Dev of Sleep efficiency ",older,'\n')

older = older_adults.groupby('Gender')['REM sleep percentage'].mean()
print("Avg of REM sleep percentage ",older )
older = older_adults.groupby('Gender')['REM sleep percentage'].std()
print("St Dev of REM sleep percentage ",older ,'\n')

older = older_adults.groupby('Gender')['Deep sleep percentage'].mean()
print("Avg of Deep sleep percentage ",older)
older = older_adults.groupby('Gender')['Deep sleep percentage'].std()
print("St Dev of Deep sleep percentage ",older ,'\n')

older = older_adults.groupby('Gender')['Light sleep percentage'].mean()
print("Avg of Light sleep percentage ",older)
older = older_adults.groupby('Gender')['Light sleep percentage'].std()
print("St Dev of Light sleep percentage ",older,'\n')

older = older_adults.groupby('Gender')['Awakenings'].mean()
print("Avg of Awakenings ",older)
older= older_adults.groupby('Gender')['Awakenings'].std()
print("St Dev of Awakenings ",older ,'\n')

older = older_adults.groupby('Gender')['Exercise frequency'].mean()
print("Avg of Exercise frequency",older)
older = older_adults.groupby('Gender')['Exercise frequency'].std()
print("St Dev of Exercise frequency ",older ,'\n')

older = older_adults.groupby('Gender')['Alcohol consumption'].mean()
print("Avg of Alcohol consumption ",older)
older= older_adults.groupby('Gender')['Alcohol consumption'].std()
print("St Dev of Alcohol consumption",older ,'\n')

older= older_adults.groupby('Gender')['Exercise frequency'].mean()
print("Avg of Exercise frequency  children",older )
older= older_adults.groupby('Gender')['Exercise frequency'].std()
print("St Dev of Exercise frequency children",older  ,'\n')
# Out:
# Avg of AGE  Gender
# Female    65.000000
# Male      66.111111
# Name: Age, dtype: float64
# St Dev of AGE  Gender
# Female    0.000000
# Male      1.536591
# Name: Age, dtype: float64
#
# Avg of Sleep duration  Gender
# Female    7.416667
# Male      7.444444
# Name: Sleep duration, dtype: float64
# St Dev of Sleep duration Gender
# Female    1.020621
# Male      1.044164
# Name: Sleep duration, dtype: float64
#
# Avg of Sleep efficiency Gender
# Female    0.786667
# Male      0.736667
# Name: Sleep efficiency, dtype: float64
# St Dev of Sleep efficiency  Gender
# Female    0.172124
# Male      0.114782
# Name: Sleep efficiency, dtype: float64
#
# Avg of REM sleep percentage  Gender
# Female    22.000000
# Male      23.777778
# Name: REM sleep percentage, dtype: float64
# St Dev of REM sleep percentage  Gender
# Female    3.577709
# Male      3.800585
# Name: REM sleep percentage, dtype: float64
#
# Avg of Deep sleep percentage  Gender
# Female    50.833333
# Male      50.444444
# ...
